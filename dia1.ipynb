# %%
print('hola mundo')
# Out:
# hola mundo

# %%
print('Datos personales') # texto que indica los requerimientos para el ejercicio, en este caso "datos personales"

#variables

nombre= 'Matias Aguayo'
edad= 28 
edadSt= 'años de edad'
ciudad= 'Asuncion'

#impresion de datos personales 

print(nombre,edad,edadSt,ciudad)
# Out:
# Datos personales
# Matias Aguayo 28 años de edad Asuncion

# %%
#challenge 2 dia 1
#variables suma 
print('venta de frutas')
cantidad_de_manzanas= 5
cantidad_de_naranjas= 7
cantidad_de_frutas= cantidad_de_manzanas + cantidad_de_naranjas
print('en total hay', cantidad_de_frutas,'frutas')
#variables resta
frutas_vendidas= 4
frutas_restantes= cantidad_de_frutas - frutas_vendidas
print('se vendieron', frutas_vendidas)
print('quedan', frutas_restantes)
# Out:
# venta de frutas
# en total hay 12 frutas
# se vendieron 4
# quedan 8

# %%
nombre= 'eduardo'
apellido= 'ovelar'
print(f'hola {nombre} { apellido}, mucho gusto')
# Out:
# hola eduardo ovelar, mucho gusto

# %%
primer_valor = int (input ('ingresa el primer valor'))
print(primer_valor)
segundo_valor = int (input('ingrese el segundo valor'))
print(segundo_valor)
print('la suma de los valores da como resultado', primer_valor+segundo_valor)
print
# Out:
# 5
# 5
# la suma de los valores da como resultado 10

# %%
#challenge 5 dia 1
#funcion
def instalacion_de_drivers():
    print('buscando actualizaciones')
    print('sobrescribiendo datos')
    print('actualizacion instalada correctamente')
    print('un pequenho aporte voluntario nos ayuda a mantener nuestros servicios')
    donacion=float(input('donacion voluntaria'))
    print('gracias por su aporte de',donacion,'dolares')
#ejecucion 
instalacion_de_drivers()   
instalacion_de_drivers() 
instalacion_de_drivers()
# Out:
# buscando actualizaciones
# sobrescribiendo datos
# actualizacion instalada correctamente
# un pequenho aporte voluntario nos ayuda a mantener nuestros servicios
# gracias por su aporte de 6.0 dolares
# buscando actualizaciones
# sobrescribiendo datos
# actualizacion instalada correctamente
# un pequenho aporte voluntario nos ayuda a mantener nuestros servicios
# gracias por su aporte de 6.7 dolares
# buscando actualizaciones
# sobrescribiendo datos
# actualizacion instalada correctamente
# un pequenho aporte voluntario nos ayuda a mantener nuestros servicios
# gracias por su aporte de 76.9 dolares

# %%
#challenge 6 dia 1
#funcion
def compra_de_componentes(a,b,c,): 
    print('indique un componente que desea')
    a=input('a') 
    print(a)
    print('indique otro componente')
    b=input('b')
    print(b)
    print('indique ultimo componente')
    c=input('c')
    print(c)
    print('pedido realizado con exito',a,b,c)
compra_de_componentes("a",'b','c')
# Out:
# indique un componente que desea
# ryzen 5
# indique otro componente
# rtx 4080
# indique ultimo componente
# 32gb ram
# pedido realizado con exito ryzen 5 rtx 4080 32gb ram

# %%
gpu=('nvidia')
def Tarjeta_garfica(serie,potencia,color):
    color=('negro')
    print('selleccione la serie de la', gpu)
    int=input(serie)
    print(serie)
    print('indique la potencia deseada')
    int=input(potencia)
    print(potencia)
    print('pedido confirmado una tarjeta grafica', gpu,'de color', color, 'de la serie',serie,'con',potencia,'de ram')
Tarjeta_garfica('serie','potencia','color')
# Out:
# selleccione la serie de la nvidia
# serie
# indique la potencia deseada
