# %%
#Crear una función que imprima la variable palabra.

# definir una variable
# crear la funcion def imprimir palabra
    #imorimir la variable palabra
#llamar a la funcion

palabra= 'hola'
def imprimir_palabra():
    print(palabra)
imprimir_palabra()
# Out:
# hola

# %%
#sumar 2  numaeros y suma:
#definir 2 variables con int(input()), numero1, numero2
#definir funcion sumar(n1,n2)
    #opcion1 crear variable n3=n1+n2
    #opcion2 print(n1+n2
#ejecutar la funcion sumar()
numero1=int(input('ingrese un numero'))
numero2=int(input('ingrese otro numero'))
def sumar(n1, n2):
    n3=n1+n2
    print(n3)
sumar(numero1,numero2)

# %%
#Crear una función que reciba dos letras (parámetros) y que verifique si son iguales:

#Si son iguales, imprimir "Las letras son iguales".

#De lo contrario, imprimir "Las letras son diferentes".
#definimos las variables
letra1=input('escriba una letra')
print(letra1)
letra2= input('escriba otra letra')
print(letra2)
#definimos la funcion con dos parametros
def verificacion_de_letras(l1,l2):
    if l1==l2:
        print('las letras son iguales')
    else:
        print('las letras no son iguales')
#llamamos la funcion usando las variables 
verificacion_de_letras(letra1,letra2)
# Out:
# j
# k
# las letras no coinciden

# %%
#rear una función que reciba dos parámetros (una palabra y un número), y que retorne True si el número es igual a la cantidad de letras de la palabra. En caso contrario, que retorne False.

#Pista: cantidad de letras de una palabra en python
#definimos las variables 
palabra= input('ingresar palabra')
print(palabra)
cantidad_de_letras=int(input('ingrese un numero'))
print(cantidad_de_letras)
#preparamos la funcion
def definir_palabra(p1,cantidad):
    if len (palabra) == cantidad_de_letras:
        return True
    else:
        return False
    
    
definir_palabra(palabra,cantidad_de_letras)
# Out:
# hola
# 8
# False

# %%
#Crear función que revise si una palabra contiene una letra. En caso de que la contenga, retornar la letra entre corchetes []. 
# De lo contrario, retornar solo la letra.
palabra=input('ingrese una palabra')
print(palabra)
letra= input('ingrese una letra')
print(letra)

def buscador(p,l):
    if l in p:
        return [l]
    else:
       return l
         
buscador(palabra,letra)
# Out:
# hola
# o
# ['o']

# %%
#
# -----------------------------------REPASAR------------------------------------------------------------------------------
# Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con list(). 
# Agregar esa lista de caracteres a una lista llamada palabras_ingresadas. Repetir el proceso 3 veces. 
# Cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas.
# definir variable  palabra
#convertir a una lista list() y guardar eb uba variable
#crear lista palabras ingresadas
#  agregar list() a una lista =[]
#palabras ingresadas.append(lista de palabras)
# probar un bucle que se repita 3 veces

for i in range (3):
    palabra= input('agregar palabra a la lista')

a
# Out:
# [['l', 'o', 'l', 'o']]

# %%
lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#recorrer la lista y que imprima cada elemento 
def imprimir(l):
    for elementos in  (lista):
        print(elementos)
imprimir(lista)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
letras_verificadas=[]
cantidad_letras=5

palabra_secreta= 'salto'
def verificadora_palabra(palabra_ingresada):
    for i in range(cantidad_letras):
        las_palabras_son_iguales = palabra_ingresada [i]== palabra_secreta [i] #true o false
        la_letra_existe_en_la_palabra= palabra_ingresada[i] in palabra_secreta
        if las_palabras_son_iguales:
            letras_verificadas.append("[",palabra_ingresada[i]"]")
    elif: 
    la_letra_existe_en_la_palabra
